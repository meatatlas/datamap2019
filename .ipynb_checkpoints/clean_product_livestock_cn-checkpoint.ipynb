# %%
import numpy as np
import pandas as pd

class ReadData():
    """
    import pandas at first
    Usage:
    df = ReadData(file_name, url).createDF() 
    """
    def __init__(self, file_name, 
                 url = None,
                 org_name = 'good-food', 
                 repo_name = 'datamap2019', 
                 folder_path = '/data/', 
                 mode = 'wb'
                ):
        
        self.file_name = file_name
        self.org_name = org_name
        self.repo_name = repo_name
        self.folder_path = folder_path
        
        self.url = url
        self.mode = mode
        
        self.root_path = 'https://github.com/'
        self.raw_path = 'https://raw.githubusercontent.com/'
        self.branch = 'master'

    def getPath(self):
        if self.url == None:
            path = self.root_path + self.org_name + '/' + self.repo_name + '/blob/' + self.branch + self.folder_path + self.file_name
            raw_path = self.raw_path + self.org_name + '/' + self.repo_name + '/' + self.branch + self.folder_path + self.file_name
            print('Url: ', path)
            print('Raw data:', raw_path)
        else:
            print('Url: ', self.url)
            print('Raw data:', self.url)
        return raw_path

    def curl(self):
        import urllib.request, urllib.parse, urllib.error
        
        url = self.getPath()
        response = urllib.request.urlopen(url).read()
        with open(self.file_name, self.mode) as file_handle:
            file_handle.write(response)

    def delFile(self):
        import os
        if os.path.exists(self.file_name): os.remove(self.file_name)
        else: print('no such file:%s'%self.file_name)

    def createDF(self):
        import time
        print(self.file_name, 'is under dealing... needs 1 min')
        self.curl()
        time.sleep(10)
        df = pd.read_csv(self.file_name)
        self.delFile()
        return df

# %%
#显示所有列
pd.set_option('display.max_columns', None)
#显示所有行
pd.set_option('display.max_rows', None)
#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)

# %%
# input
item = 'product_livestock_cn'

# output
data_stock = item + '_stock.csv'
data_primary = item + '_primary.csv'

# %%
# If you haven't cloned the whole repository from 
# [Github](https://github.com/good-food/datamap2019)
# please uncomment and run the top 2 lines 
# or else, run the bottom 2 lines or clone the reporsitory at first.
# ------------------------------------------------------------------

# df_stock = ReadData(data_stock).createDF()
# df_primary = ReadData(data_primary).createDF()

df_stock = pd.read_csv('./data/'+data_stock)
df_primary = pd.read_csv('./data/'+data_primary)

# %%
df_prod = pd.concat([df_stock, df_primary], axis=0,join='outer')
print('shape of df_stock.shape is {}\nshape of df_primary.shape is {}\nshape of df_prod.shape is {}'.format(df_stock.shape, df_primary.shape, df_prod.shape))
# Out:
# shape of df_stock.shape is (1368, 14)
# shape of df_primary.shape is (7090, 14)
# shape of df_prod.shape is (8458, 14)

# %%
df_prod.head()
# Out:
#   Domain Code        Domain  Area Code   Area  Element Code Element  \
# 0          QA  Live Animals        351  China          5111  Stocks
# 1          QA  Live Animals        351  China          5111  Stocks
# 2          QA  Live Animals        351  China          5111  Stocks
# 3          QA  Live Animals        351  China          5111  Stocks
# 4          QA  Live Animals        351  China          5111  Stocks
#
#    Item Code              Item  Year Code  Year  Unit     Value Flag  \
# 0       1171  Animals live nes       1961  1961  Head  415450.0    A
# 1       1171  Animals live nes       1962  1962  Head  587400.0    A
# 2       1171  Animals live nes       1963  1963  Head  587665.0    A
# 3       1171  Animals live nes       1964  1964  Head  510730.0    A
# 4       1171  Animals live nes       1965  1965  Head  255065.0    A
#
#                                                                Flag Description
# 0  Aggregate, may include official, semi-official, estimated or calculated data
# 1  Aggregate, may include official, semi-official, estimated or calculated data
# 2  Aggregate, may include official, semi-official, estimated or calculated data
# 3  Aggregate, may include official, semi-official, estimated or calculated data
# 4  Aggregate, may include official, semi-official, estimated or calculated data

# %%
df_prod.drop(columns = ['Domain Code', 'Area Code', 'Element Code', 'Item Code', 'Year Code', 'Flag'], inplace=True)
df_prod.head()
# Out:
#          Domain   Area Element              Item  Year  Unit     Value  \
# 0  Live Animals  China  Stocks  Animals live nes  1961  Head  415450.0
# 1  Live Animals  China  Stocks  Animals live nes  1962  Head  587400.0
# 2  Live Animals  China  Stocks  Animals live nes  1963  Head  587665.0
# 3  Live Animals  China  Stocks  Animals live nes  1964  Head  510730.0
# 4  Live Animals  China  Stocks  Animals live nes  1965  Head  255065.0
#
#                                                                Flag Description
# 0  Aggregate, may include official, semi-official, estimated or calculated data
# 1  Aggregate, may include official, semi-official, estimated or calculated data
# 2  Aggregate, may include official, semi-official, estimated or calculated data
# 3  Aggregate, may include official, semi-official, estimated or calculated data
# 4  Aggregate, may include official, semi-official, estimated or calculated data

# %%
df = df_prod.dropna()
df.describe(include='all')
# Out:
#                    Domain   Area     Element           Item         Year  \
# count                7919   7919        7919           7919  7919.000000
# unique                  2      1           8             66          NaN
# top     Livestock Primary  China  Production  Meat, buffalo          NaN
# freq                 6951   7919        3337            171          NaN
# mean                  NaN    NaN         NaN            NaN  1988.465084
# std                   NaN    NaN         NaN            NaN    16.057723
# min                   NaN    NaN         NaN            NaN  1961.000000
# 25%                   NaN    NaN         NaN            NaN  1975.000000
# 50%                   NaN    NaN         NaN            NaN  1989.000000
# 75%                   NaN    NaN         NaN            NaN  2002.000000
# max                   NaN    NaN         NaN            NaN  2017.000000
#
#           Unit         Value  \
# count     7919  7.919000e+03
# unique       9           NaN
# top     tonnes           NaN
# freq      2457           NaN
# mean       NaN  1.513920e+07
# std        NaN  6.255401e+07
# min        NaN  0.000000e+00
# 25%        NaN  7.500000e+03
# 50%        NaN  1.446840e+05
# 75%        NaN  2.002374e+06
# max        NaN  7.449064e+08
#
#                                                                     Flag Description
# count                                                                           7919
# unique                                                                             2
# top     Aggregate, may include official, semi-official, estimated or calculated data
# freq                                                                            5742
# mean                                                                             NaN
# std                                                                              NaN
# min                                                                              NaN
# 25%                                                                              NaN
# 50%                                                                              NaN
# 75%                                                                              NaN
# max                                                                              NaN

# %%
df.groupby('Element').count()
# Out:
#                                Domain  Area  Item  Year  Unit  Value  \
# Element
# Laying                             57    57    57    57    57     57
# Milk Animals                      285   285   285   285   285    285
# Prod Popultn                       57    57    57    57    57     57
# Producing Animals/Slaughtered    1038  1038  1038  1038  1038   1038
# Production                       3337  3337  3337  3337  3337   3337
# Stocks                            968   968   968   968   968    968
# Yield                             611   611   611   611   611    611
# Yield/Carcass Weight             1566  1566  1566  1566  1566   1566
#
#                                Flag Description
# Element
# Laying                                       57
# Milk Animals                                285
# Prod Popultn                                 57
# Producing Animals/Slaughtered              1038
# Production                                 3337
# Stocks                                      968
# Yield                                       611
# Yield/Carcass Weight                       1566

# %%
df.groupby('Item').count()
# Out:
#                                      Domain  Area  Element  Year  Unit  Value  \
# Item
# Animals live nes                         56    56       56    56    56     56
# Asses                                    57    57       57    57    57     57
# Beehives                                 57    57       57    57    57     57
# Buffaloes                                57    57       57    57    57     57
# Camels                                   57    57       57    57    57     57
# Cattle                                   57    57       57    57    57     57
# Chickens                                 57    57       57    57    57     57
# Ducks                                    57    57       57    57    57     57
# Eggs, hen, in shell                     171   171      171   171   171    171
# Eggs, hen, in shell (number)             57    57       57    57    57     57
# Eggs, other bird, in shell               57    57       57    57    57     57
# Eggs, other bird, in shell (number)      57    57       57    57    57     57
# Geese and guinea fowls                   57    57       57    57    57     57
# Goats                                    57    57       57    57    57     57
# Hides, buffalo, fresh                   159   159      159   159   159    159
# Hides, cattle, fresh                    159   159      159   159   159    159
# Honey, natural                          171   171      171   171   171    171
# Horses                                   57    57       57    57    57     57
# Meat indigenous, ass                    159   159      159   159   159    159
# Meat indigenous, bird nes                24    24       24    24    24     24
# Meat indigenous, buffalo                159   159      159   159   159    159
# Meat indigenous, camel                  159   159      159   159   159    159
# Meat indigenous, cattle                 159   159      159   159   159    159
# Meat indigenous, chicken                159   159      159   159   159    159
# Meat indigenous, duck                   159   159      159   159   159    159
# Meat indigenous, geese                  159   159      159   159   159    159
# Meat indigenous, goat                   159   159      159   159   159    159
# Meat indigenous, horse                  159   159      159   159   159    159
# Meat indigenous, mule                   159   159      159   159   159    159
# Meat indigenous, pig                    159   159      159   159   159    159
# Meat indigenous, rabbit                 159   159      159   159   159    159
# Meat indigenous, sheep                  159   159      159   159   159    159
# Meat indigenous, turkey                 159   159      159   159   159    159
# Meat, ass                               171   171      171   171   171    171
# Meat, bird nes                           82    82       82    82    82     82
# Meat, buffalo                           171   171      171   171   171    171
# Meat, camel                             171   171      171   171   171    171
# Meat, cattle                            171   171      171   171   171    171
# Meat, chicken                           171   171      171   171   171    171
# Meat, duck                              171   171      171   171   171    171
# Meat, game                               52    52       52    52    52     52
# Meat, goat                              171   171      171   171   171    171
# Meat, goose and guinea fowl             171   171      171   171   171    171
# Meat, horse                             171   171      171   171   171    171
# Meat, mule                              171   171      171   171   171    171
# Meat, nes                                57    57       57    57    57     57
# Meat, pig                               171   171      171   171   171    171
# Meat, rabbit                            171   171      171   171   171    171
# Meat, sheep                             171   171      171   171   171    171
# Meat, turkey                            171   171      171   171   171    171
# Milk, whole fresh buffalo               171   171      171   171   171    171
# Milk, whole fresh camel                 171   171      171   171   171    171
# Milk, whole fresh cow                   171   171      171   171   171    171
# Milk, whole fresh goat                  171   171      171   171   171    171
# Milk, whole fresh sheep                 171   171      171   171   171    171
# Mules                                    57    57       57    57    57     57
# Offals, nes                               2     2        2     2     2      2
# Pigeons, other birds                     57    57       57    57    57     57
# Pigs                                     57    57       57    57    57     57
# Rabbits and hares                        57    57       57    57    57     57
# Sheep                                    57    57       57    57    57     57
# Silk-worm cocoons, reelable              57    57       57    57    57     57
# Skins, goat, fresh                      159   159      159   159   159    159
# Skins, sheep, fresh                     159   159      159   159   159    159
# Turkeys                                  57    57       57    57    57     57
# Wool, greasy                             53    53       53    53    53     53
#
#                                      Flag Description
# Item
# Animals live nes                                   56
# Asses                                              57
# Beehives                                           57
# Buffaloes                                          57
# Camels                                             57
# Cattle                                             57
# Chickens                                           57
# Ducks                                              57
# Eggs, hen, in shell                               171
# Eggs, hen, in shell (number)                       57
# Eggs, other bird, in shell                         57
# Eggs, other bird, in shell (number)                57
# Geese and guinea fowls                             57
# Goats                                              57
# Hides, buffalo, fresh                             159
# Hides, cattle, fresh                              159
# Honey, natural                                    171
# Horses                                             57
# Meat indigenous, ass                              159
# Meat indigenous, bird nes                          24
# Meat indigenous, buffalo                          159
# Meat indigenous, camel                            159
# Meat indigenous, cattle                           159
# Meat indigenous, chicken                          159
# Meat indigenous, duck                             159
# Meat indigenous, geese                            159
# Meat indigenous, goat                             159
# Meat indigenous, horse                            159
# Meat indigenous, mule                             159
# Meat indigenous, pig                              159
# Meat indigenous, rabbit                           159
# Meat indigenous, sheep                            159
# Meat indigenous, turkey                           159
# Meat, ass                                         171
# Meat, bird nes                                     82
# Meat, buffalo                                     171
# Meat, camel                                       171
# Meat, cattle                                      171
# Meat, chicken                                     171
# Meat, duck                                        171
# Meat, game                                         52
# Meat, goat                                        171
# Meat, goose and guinea fowl                       171
# Meat, horse                                       171
# Meat, mule                                        171
# Meat, nes                                          57
# Meat, pig                                         171
# Meat, rabbit                                      171
# Meat, sheep                                       171
# Meat, turkey                                      171
# Milk, whole fresh buffalo                         171
# Milk, whole fresh camel                           171
# Milk, whole fresh cow                             171
# Milk, whole fresh goat                            171
# Milk, whole fresh sheep                           171
# Mules                                              57
# Offals, nes                                         2
# Pigeons, other birds                               57
# Pigs                                               57
# Rabbits and hares                                  57
# Sheep                                              57
# Silk-worm cocoons, reelable                        57
# Skins, goat, fresh                                159
# Skins, sheep, fresh                               159
# Turkeys                                            57
# Wool, greasy                                       53

# %%
elements = df['Element'].unique()
elements
# Out:
# array(['Stocks', 'Laying', 'Yield', 'Production',
#        'Producing Animals/Slaughtered', 'Prod Popultn',
#        'Yield/Carcass Weight', 'Milk Animals'], dtype=object)

# %%
df = df.loc[df['Element'].isin(['Stocks', 'Producing Animals/Slaughtered', 'Production', 'Yield/Carcass Weight'])]
df.head()
# Out:
#          Domain   Area Element              Item  Year  Unit     Value  \
# 0  Live Animals  China  Stocks  Animals live nes  1961  Head  415450.0
# 1  Live Animals  China  Stocks  Animals live nes  1962  Head  587400.0
# 2  Live Animals  China  Stocks  Animals live nes  1963  Head  587665.0
# 3  Live Animals  China  Stocks  Animals live nes  1964  Head  510730.0
# 4  Live Animals  China  Stocks  Animals live nes  1965  Head  255065.0
#
#                                                                Flag Description
# 0  Aggregate, may include official, semi-official, estimated or calculated data
# 1  Aggregate, may include official, semi-official, estimated or calculated data
# 2  Aggregate, may include official, semi-official, estimated or calculated data
# 3  Aggregate, may include official, semi-official, estimated or calculated data
# 4  Aggregate, may include official, semi-official, estimated or calculated data

# %%
df = df.loc[df['Item'].isin([
    # stock
    'Cattle', 'Camels', 'Horses', 'Mules',                          
    'Goats', 'Sheep', 'Pigs',
    'Chickens', 'Ducks', 'Geese and guinea fowls',
    # meat
    'Meat, cattle', 'Meat, camel', 'Meat, horse', 'Meat, mules',
    'Meat, goat', 'Meat, sheep', 'Meat, pig',
    'Meat, chicken', 'Meat, duck', 'Meat, goose and guinea fowl',
    # egg
    'Eggs, hen, in shell', 'Eggs, other bird, in shell',
    # milk
    'Milk, whole fresh cow', 'Milk, whole fresh camel',
    'Milk, whole fresh goat', 'Milk, whole fresh sheep'])]
df.shape
# Out:
# (2451, 8)

# %%
df.groupby(['Element', 'Item']).count()
# Out:
#                                                            Domain  Area  Year  \
# Element                       Item
# Producing Animals/Slaughtered Meat, camel                      57    57    57
#                               Meat, cattle                     57    57    57
#                               Meat, chicken                    57    57    57
#                               Meat, duck                       57    57    57
#                               Meat, goat                       57    57    57
#                               Meat, goose and guinea fowl      57    57    57
#                               Meat, horse                      57    57    57
#                               Meat, pig                        57    57    57
#                               Meat, sheep                      57    57    57
# Production                    Eggs, hen, in shell              57    57    57
#                               Eggs, other bird, in shell       57    57    57
#                               Meat, camel                      57    57    57
#                               Meat, cattle                     57    57    57
#                               Meat, chicken                    57    57    57
#                               Meat, duck                       57    57    57
#                               Meat, goat                       57    57    57
#                               Meat, goose and guinea fowl      57    57    57
#                               Meat, horse                      57    57    57
#                               Meat, pig                        57    57    57
#                               Meat, sheep                      57    57    57
#                               Milk, whole fresh camel          57    57    57
#                               Milk, whole fresh cow            57    57    57
#                               Milk, whole fresh goat           57    57    57
#                               Milk, whole fresh sheep          57    57    57
# Stocks                        Camels                           57    57    57
#                               Cattle                           57    57    57
#                               Chickens                         57    57    57
#                               Ducks                            57    57    57
#                               Geese and guinea fowls           57    57    57
#                               Goats                            57    57    57
#                               Horses                           57    57    57
#                               Mules                            57    57    57
#                               Pigs                             57    57    57
#                               Sheep                            57    57    57
# Yield/Carcass Weight          Meat, camel                      57    57    57
#                               Meat, cattle                     57    57    57
#                               Meat, chicken                    57    57    57
#                               Meat, duck                       57    57    57
#                               Meat, goat                       57    57    57
#                               Meat, goose and guinea fowl      57    57    57
#                               Meat, horse                      57    57    57
#                               Meat, pig                        57    57    57
#                               Meat, sheep                      57    57    57
#
#                                                            Unit  Value  \
# Element                       Item
# Producing Animals/Slaughtered Meat, camel                    57     57
#                               Meat, cattle                   57     57
#                               Meat, chicken                  57     57
#                               Meat, duck                     57     57
#                               Meat, goat                     57     57
#                               Meat, goose and guinea fowl    57     57
#                               Meat, horse                    57     57
#                               Meat, pig                      57     57
#                               Meat, sheep                    57     57
# Production                    Eggs, hen, in shell            57     57
#                               Eggs, other bird, in shell     57     57
#                               Meat, camel                    57     57
#                               Meat, cattle                   57     57
#                               Meat, chicken                  57     57
#                               Meat, duck                     57     57
#                               Meat, goat                     57     57
#                               Meat, goose and guinea fowl    57     57
#                               Meat, horse                    57     57
#                               Meat, pig                      57     57
#                               Meat, sheep                    57     57
#                               Milk, whole fresh camel        57     57
#                               Milk, whole fresh cow          57     57
#                               Milk, whole fresh goat         57     57
#                               Milk, whole fresh sheep        57     57
# Stocks                        Camels                         57     57
#                               Cattle                         57     57
#                               Chickens                       57     57
#                               Ducks                          57     57
#                               Geese and guinea fowls         57     57
#                               Goats                          57     57
#                               Horses                         57     57
#                               Mules                          57     57
#                               Pigs                           57     57
#                               Sheep                          57     57
# Yield/Carcass Weight          Meat, camel                    57     57
#                               Meat, cattle                   57     57
#                               Meat, chicken                  57     57
#                               Meat, duck                     57     57
#                               Meat, goat                     57     57
#                               Meat, goose and guinea fowl    57     57
#                               Meat, horse                    57     57
#                               Meat, pig                      57     57
#                               Meat, sheep                    57     57
#
#                                                            Flag Description
# Element                       Item
# Producing Animals/Slaughtered Meat, camel                                57
#                               Meat, cattle                               57
#                               Meat, chicken                              57
#                               Meat, duck                                 57
#                               Meat, goat                                 57
#                               Meat, goose and guinea fowl                57
#                               Meat, horse                                57
#                               Meat, pig                                  57
#                               Meat, sheep                                57
# Production                    Eggs, hen, in shell                        57
#                               Eggs, other bird, in shell                 57
#                               Meat, camel                                57
#                               Meat, cattle                               57
#                               Meat, chicken                              57
#                               Meat, duck                                 57
#                               Meat, goat                                 57
#                               Meat, goose and guinea fowl                57
#                               Meat, horse                                57
#                               Meat, pig                                  57
#                               Meat, sheep                                57
#                               Milk, whole fresh camel                    57
#                               Milk, whole fresh cow                      57
#                               Milk, whole fresh goat                     57
#                               Milk, whole fresh sheep                    57
# Stocks                        Camels                                     57
#                               Cattle                                     57
#                               Chickens                                   57
#                               Ducks                                      57
#                               Geese and guinea fowls                     57
#                               Goats                                      57
#                               Horses                                     57
#                               Mules                                      57
#                               Pigs                                       57
#                               Sheep                                      57
# Yield/Carcass Weight          Meat, camel                                57
#                               Meat, cattle                               57
#                               Meat, chicken                              57
#                               Meat, duck                                 57
#                               Meat, goat                                 57
#                               Meat, goose and guinea fowl                57
#                               Meat, horse                                57
#                               Meat, pig                                  57
#                               Meat, sheep                                57

# %%
df['Unit'].unique()
# Out:
# array(['Head', '1000 Head', 'tonnes', 'hg/An', '0.1g/An'], dtype=object)

# %%
df.loc[df['Unit']=='Head'].head()
# Out:
#            Domain   Area Element    Item  Year  Unit     Value  \
# 285  Live Animals  China  Stocks  Camels  1961  Head  381000.0
# 286  Live Animals  China  Stocks  Camels  1962  Head  378000.0
# 287  Live Animals  China  Stocks  Camels  1963  Head  386000.0
# 288  Live Animals  China  Stocks  Camels  1964  Head  402000.0
# 289  Live Animals  China  Stocks  Camels  1965  Head  425000.0
#
#                                                                  Flag Description
# 285  Aggregate, may include official, semi-official, estimated or calculated data
# 286  Aggregate, may include official, semi-official, estimated or calculated data
# 287  Aggregate, may include official, semi-official, estimated or calculated data
# 288  Aggregate, may include official, semi-official, estimated or calculated data
# 289  Aggregate, may include official, semi-official, estimated or calculated data

# %%
df.loc[df['Unit']=='1000 Head'].head()
# Out:
#            Domain   Area Element      Item  Year       Unit     Value  \
# 456  Live Animals  China  Stocks  Chickens  1961  1000 Head  540850.0
# 457  Live Animals  China  Stocks  Chickens  1962  1000 Head  554423.0
# 458  Live Animals  China  Stocks  Chickens  1963  1000 Head  570972.0
# 459  Live Animals  China  Stocks  Chickens  1964  1000 Head  586801.0
# 460  Live Animals  China  Stocks  Chickens  1965  1000 Head  590895.0
#
#                                                                  Flag Description
# 456  Aggregate, may include official, semi-official, estimated or calculated data
# 457  Aggregate, may include official, semi-official, estimated or calculated data
# 458  Aggregate, may include official, semi-official, estimated or calculated data
# 459  Aggregate, may include official, semi-official, estimated or calculated data
# 460  Aggregate, may include official, semi-official, estimated or calculated data

# %%
df.loc[df['Unit']=='tonnes'].head()
# Out:
#                 Domain   Area     Element                 Item  Year    Unit  \
# 114  Livestock Primary  China  Production  Eggs, hen, in shell  1961  tonnes
# 115  Livestock Primary  China  Production  Eggs, hen, in shell  1962  tonnes
# 116  Livestock Primary  China  Production  Eggs, hen, in shell  1963  tonnes
# 117  Livestock Primary  China  Production  Eggs, hen, in shell  1964  tonnes
# 118  Livestock Primary  China  Production  Eggs, hen, in shell  1965  tonnes
#
#          Value  \
# 114  1211565.0
# 115  1229591.0
# 116  1247638.0
# 117  1282830.0
# 118  1313836.0
#
#                                                                  Flag Description
# 114  Aggregate, may include official, semi-official, estimated or calculated data
# 115  Aggregate, may include official, semi-official, estimated or calculated data
# 116  Aggregate, may include official, semi-official, estimated or calculated data
# 117  Aggregate, may include official, semi-official, estimated or calculated data
# 118  Aggregate, may include official, semi-official, estimated or calculated data

# %%
df.loc[df['Unit']=='hg/An'].head()
# Out:
#                  Domain   Area               Element         Item  Year  \
# 3649  Livestock Primary  China  Yield/Carcass Weight  Meat, camel  1961
# 3650  Livestock Primary  China  Yield/Carcass Weight  Meat, camel  1962
# 3651  Livestock Primary  China  Yield/Carcass Weight  Meat, camel  1963
# 3652  Livestock Primary  China  Yield/Carcass Weight  Meat, camel  1964
# 3653  Livestock Primary  China  Yield/Carcass Weight  Meat, camel  1965
#
#        Unit   Value Flag Description
# 3649  hg/An  2200.0  Calculated data
# 3650  hg/An  2200.0  Calculated data
# 3651  hg/An  2200.0  Calculated data
# 3652  hg/An  2200.0  Calculated data
# 3653  hg/An  2200.0  Calculated data

# %%
df.loc[df['Unit']=='0.1g/An'].head()
# Out:
#                  Domain   Area               Element           Item  Year  \
# 3991  Livestock Primary  China  Yield/Carcass Weight  Meat, chicken  1961
# 3992  Livestock Primary  China  Yield/Carcass Weight  Meat, chicken  1962
# 3993  Livestock Primary  China  Yield/Carcass Weight  Meat, chicken  1963
# 3994  Livestock Primary  China  Yield/Carcass Weight  Meat, chicken  1964
# 3995  Livestock Primary  China  Yield/Carcass Weight  Meat, chicken  1965
#
#          Unit    Value Flag Description
# 3991  0.1g/An  10144.0  Calculated data
# 3992  0.1g/An  10141.0  Calculated data
# 3993  0.1g/An  10144.0  Calculated data
# 3994  0.1g/An  10146.0  Calculated data
# 3995  0.1g/An  10149.0  Calculated data

# %%
df.loc[df['Unit'] =='Head','Value']=df['Value']/10000
df.loc[df['Unit']=='Head', 'Unit']= '10000 Head'

df.loc[df['Unit'] =='1000 Head','Value']=df['Value']/10
df.loc[df['Unit']=='1000 Head', 'Unit']= '10000 Head'

df.loc[df['Unit'] =='tonnes','Value']=df['Value']/10000
df.loc[df['Unit']=='tonnes', 'Unit']= '10000 tonnes'

df.loc[df['Unit'] =='hg/An','Value']=df['Value']/10
df.loc[df['Unit']=='hg/An', 'Unit']= 'kg/An'

df.loc[df['Unit'] =='0.1g/An','Value']=df['Value']/10
df.loc[df['Unit']=='0.1g/An', 'Unit']= 'g/An'

# %%
df['Unit'].unique()
# Out:
# array(['10000 Head', '10000 tonnes', 'kg/An', 'g/An'], dtype=object)

# %%
df.loc[df['Unit']=='10000 Head'].head()
# Out:
#            Domain   Area Element    Item  Year        Unit  Value  \
# 285  Live Animals  China  Stocks  Camels  1961  10000 Head   38.1
# 286  Live Animals  China  Stocks  Camels  1962  10000 Head   37.8
# 287  Live Animals  China  Stocks  Camels  1963  10000 Head   38.6
# 288  Live Animals  China  Stocks  Camels  1964  10000 Head   40.2
# 289  Live Animals  China  Stocks  Camels  1965  10000 Head   42.5
#
#                                                                  Flag Description
# 285  Aggregate, may include official, semi-official, estimated or calculated data
# 286  Aggregate, may include official, semi-official, estimated or calculated data
# 287  Aggregate, may include official, semi-official, estimated or calculated data
# 288  Aggregate, may include official, semi-official, estimated or calculated data
# 289  Aggregate, may include official, semi-official, estimated or calculated data

# %%
df.loc[df['Unit']=='10000 tonnes'].head()
# Out:
#                 Domain   Area     Element                 Item  Year  \
# 114  Livestock Primary  China  Production  Eggs, hen, in shell  1961
# 115  Livestock Primary  China  Production  Eggs, hen, in shell  1962
# 116  Livestock Primary  China  Production  Eggs, hen, in shell  1963
# 117  Livestock Primary  China  Production  Eggs, hen, in shell  1964
# 118  Livestock Primary  China  Production  Eggs, hen, in shell  1965
#
#              Unit     Value  \
# 114  10000 tonnes  121.1565
# 115  10000 tonnes  122.9591
# 116  10000 tonnes  124.7638
# 117  10000 tonnes  128.2830
# 118  10000 tonnes  131.3836
#
#                                                                  Flag Description
# 114  Aggregate, may include official, semi-official, estimated or calculated data
# 115  Aggregate, may include official, semi-official, estimated or calculated data
# 116  Aggregate, may include official, semi-official, estimated or calculated data
# 117  Aggregate, may include official, semi-official, estimated or calculated data
# 118  Aggregate, may include official, semi-official, estimated or calculated data

# %%
df.loc[df['Unit']=='kg/An'].head()
# Out:
#                  Domain   Area               Element         Item  Year  \
# 3649  Livestock Primary  China  Yield/Carcass Weight  Meat, camel  1961
# 3650  Livestock Primary  China  Yield/Carcass Weight  Meat, camel  1962
# 3651  Livestock Primary  China  Yield/Carcass Weight  Meat, camel  1963
# 3652  Livestock Primary  China  Yield/Carcass Weight  Meat, camel  1964
# 3653  Livestock Primary  China  Yield/Carcass Weight  Meat, camel  1965
#
#        Unit  Value Flag Description
# 3649  kg/An  220.0  Calculated data
# 3650  kg/An  220.0  Calculated data
# 3651  kg/An  220.0  Calculated data
# 3652  kg/An  220.0  Calculated data
# 3653  kg/An  220.0  Calculated data

# %%
df.loc[df['Unit']=='g/An'].head()
# Out:
#                  Domain   Area               Element           Item  Year  \
# 3991  Livestock Primary  China  Yield/Carcass Weight  Meat, chicken  1961
# 3992  Livestock Primary  China  Yield/Carcass Weight  Meat, chicken  1962
# 3993  Livestock Primary  China  Yield/Carcass Weight  Meat, chicken  1963
# 3994  Livestock Primary  China  Yield/Carcass Weight  Meat, chicken  1964
# 3995  Livestock Primary  China  Yield/Carcass Weight  Meat, chicken  1965
#
#       Unit   Value Flag Description
# 3991  g/An  1014.4  Calculated data
# 3992  g/An  1014.1  Calculated data
# 3993  g/An  1014.4  Calculated data
# 3994  g/An  1014.6  Calculated data
# 3995  g/An  1014.9  Calculated data

# %%
df.shape
# Out:
# (2451, 8)

# %%
df.to_csv('./data/product_livestock_cn_clean.csv', index=False)
