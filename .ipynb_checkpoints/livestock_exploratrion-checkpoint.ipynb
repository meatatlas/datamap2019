# %%
class ReadData():
    """
    # Usage:
    # df = ReadData(file_name, url).createDF() 
    """
    def __init__(self, file_name, 
                 url = None,
                 org_name = 'good-food', 
                 repo_name = 'datamap2019', 
                 folder_path = '/data/', 
                 mode = 'wb'
                ):
        
        self.file_name = file_name
        self.org_name = org_name
        self.repo_name = repo_name
        self.folder_path = folder_path
        
        self.url = url
        self.mode = mode
        
        self.root_path = 'https://github.com/'
        self.raw_path = 'https://raw.githubusercontent.com/'
        self.branch = 'master'

    def getPath(self):
        if self.url == None:
            path = self.root_path + self.org_name + '/' + self.repo_name + '/blob/' + self.branch + self.folder_path + self.file_name
            raw_path = self.raw_path + self.org_name + '/' + self.repo_name + '/' + self.branch + self.folder_path + self.file_name
        else:
            raw_path = self.url
            
        print('Url: ', path)
        print('Raw data:', raw_path)
        return raw_path

    def curl(self):
        import urllib.request, urllib.parse, urllib.error
        
        url = self.getPath()
        response = urllib.request.urlopen(url).read()
        with open(self.file_name, self.mode) as file_handle:
            file_handle.write(response)

    def delFile(self):
        import os

        if os.path.exists(self.file_name):
            os.remove(self.file_name)
        else:
            print('no such file:%s'%self.file_name)

    def createDF(self):
        import pandas as pd
        print(data_name, 'is under dealing...')
        self.curl()
        df = pd.read_csv(self.file_name)
        self.delFile()
        return df

# %%
# input
item = 'product_livestock'

# %%
data_name = item + '_clean.csv'
df_data = ReadData(data_name).createDF()
df_data.head()
# Out:
# product_livestock_clean.csv is under dealing...
# Url:  https://github.com/good-food/datamap2019/blob/master/data/product_livestock_clean.csv
# Raw data: https://raw.githubusercontent.com/good-food/datamap2019/master/data/product_livestock_clean.csv
#   AreaName  Year  Stock_largeAni  Stock_cattle  Stock_horse  Stock_donkey  \
# 0    China  1996        13360.60      11031.80       871.50        944.40
# 1    China  1997        14541.80      12175.70       891.20        952.80
# 2    China  1998        14803.20      12441.90       898.10        955.80
# 3    China  1999        15024.75      12698.34       891.41        934.77
# 4    China  2000        15151.51      12866.34       876.58        922.73
#
#    Stock_mule  Stock_camel   Out_hog  Stock_hog     ...      MeatYeild_gt_shp  \
# 0      478.00        34.90  41225.10   36283.60     ...            181.000000
# 1      480.60        35.00  46483.70   40034.80     ...            212.800000
# 2      473.90        33.50  50215.10   42256.30     ...            234.600000
# 3      467.27        32.96  51977.20   43144.20     ...            251.264300
# 4      453.03        32.62  52673.34   44681.54     ...            273.958296
#
#     MilkYeild  MilkYeild_cattle  WoolYeild_sheep  WoolYeild_sheep_fine  \
# 0  735.800000         629.40000         298102.0              121020.0
# 1  681.100000         601.10000         255059.0              116054.0
# 2  745.400000         662.90000         277545.0              115752.0
# 3  806.907300         717.59390         283152.0              114103.0
# 4  919.118908         827.43079         292502.0              117386.0
#
#    WoolYeild_sheep_semi  WoolYeild_goat_thick  WoolYeild_goat_cashmere  \
# 0               74099.0               35255.0                  9585.00
# 1               55683.0               25865.0                  8626.00
# 2               68775.0               31417.0                  9799.00
# 3               73700.0               31849.0                 10179.65
# 4               84921.0               33266.0                 11057.00
#
#    EggYeild  HoneyYeild
# 0  1965.200     18.4000
# 1  1895.300     21.1000
# 2  2021.300     20.7000
# 3  2134.667     22.9907
# 4  2243.300     24.6000
#
# [5 rows x 30 columns]

# %%
doc_name = item + '_doc.csv'
df_doc = ReadData(doc_name).createDF()
df_doc
# Out:
# product_livestock_clean.csv is under dealing...
# Url:  https://github.com/good-food/datamap2019/blob/master/data/product_livestock_doc.csv
# Raw data: https://raw.githubusercontent.com/good-food/datamap2019/master/data/product_livestock_doc.csv
#                  Feild name                   中文解释  \
# 0                  AreaName                地区 (省级)
# 1                      Year                     年份
# 2            Stock_largeAni    大动物存栏量 (牛&马&驴&骡&骆驼)
# 3              Stock_cattle                   牛存栏量
# 4               Stock_horse                   马存栏量
# 5              Stock_donkey                   驴存栏量
# 6                Stock_mule                   骡存栏量
# 7               Stock_camel                  骆驼存栏量
# 8                   Out_hog                   猪出栏量
# 9                 Stock_hog                   猪存栏量
# 10             Stock_gt_shp           羊存栏量 (绵羊&山羊)
# 11               Stock_goat                  山羊存栏量
# 12              Stock_sheep                  绵羊存栏量
# 13               Out_cattle                   牛出栏量
# 14               Out_gt_shp                   羊出栏量
# 15              Out_poultry                  家禽出栏量
# 16                MeatYeild            肉类产量 (所有品类)
# 17   MeatYeild_hg_ct_gt_shp  主要家畜的肉类产量 (牛&猪&山羊&绵羊)
# 18            MeatYeild_hog                   猪肉产量
# 19         MeatYeild_cattle                   牛肉产量
# 20         MeatYeild_gt_shp           羊肉产量 (山羊&绵羊)
# 21                MilkYeild             奶产量 (所有品类)
# 22         MilkYeild_cattle                   牛奶产量
# 23          WoolYeild_sheep        绵羊毛产量 (所有绵羊毛品类)
# 24     WoolYeild_sheep_fine                 细绵羊毛产量
# 25     WoolYeild_sheep_semi                半细绵羊毛产量
# 26     WoolYeild_goat_thick                 粗山羊毛产量
# 27  WoolYeild_goat_cashmere                  山羊绒产量
# 28                 EggYeild                   禽蛋产量
# 29               HoneyYeild                   蜂蜜产量
#
#                                 Explanation     单位: Unit
# 0                         Area (provincial)          Nan
# 1                                      Year          Nan
# 2   Stock of cattle&hores&donkey&mule&camel  万只: 10000 #
# 3                           Stock of cattle  万只: 10000 #
# 4                            Stock of horse  万只: 10000 #
# 5                           Stock of donkey  万只: 10000 #
# 6                             Stock of mule  万只: 10000 #
# 7                            Stock of camel  万只: 10000 #
# 8                             Output of hog  万只: 10000 #
# 9                              Stock of hog  万只: 10000 #
# 10                      Stock of sheep&goat  万只: 10000 #
# 11                            Stock of goat  万只: 10000 #
# 12                           Stock of sheep  万只: 10000 #
# 13                         Output of cattle  万只: 10000 #
# 14                          Output of sheep  万只: 10000 #
# 15                        Output of poultry  万只: 10000 #
# 16    Meat yeild from all kind of livestock  万吨: 10000 t
# 17    Meat yeild from cattle&hog&goat&sheep  万吨: 10000 t
# 18                      Meat yeild from hog  万吨: 10000 t
# 19                   Meat yeild from cattle  万吨: 10000 t
# 20               Meat yeild from goat&sheep  万吨: 10000 t
# 21    Milk yeild from all kind of livestock  万吨: 10000 t
# 22                   Milk yeild from cattle  万吨: 10000 t
# 23            Wool yeild from sheep (total)         吨: t
# 24             Wool yeild from sheep (fine)         吨: t
# 25        Wool yeild from sheep (semi-fine)         吨: t
# 26             Wool yeild from goat (thick)         吨: t
# 27          Wool yeild from goat (cashmere)         吨: t
# 28                   Egg yeild from poultry  万吨: 10000 t
# 29                              Honey yeild  万吨: 10000 t

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Group the Columns We Interested in
#
# We are interested in the following columns, and they can be grouped for further analysis (the columns may overlaped in defferent groups):
#
# - Cattle, hog, goat&sheep ('CHGS' for short):
#     - 'Stock_cattle', 'Stock_hog', 'Stock_gt_shp',
#     - 'Out_cattle', 'Out_hog', 'Out_gt_shp'
#     - 'MeatYeild_cattle', 'MeatYeild_hog', 'MeatYeild_gt_shp'
#     - 'Stock_cattle', 'Out_cattle'
#     - 'Stock_hog', 'Out_hog'
#     - 'Stock_gt_shp', 'Out_gt_shp'
#
#
# - Poultry ('birds' for short):
#     - 'Out_poultry',
#     - 'EggYeild'
#
#
# - Animal product yeilds ('yeilds' for short):
#     - 'MeatYeild_cattle', 'MeatYeild_hog', 'MeatYeild_gt_shp', 'MilkYeild', 'EggYeild'

# %%
# Stocks, outputs, and meat yeilds of cattle, hog, and goat&sheep.
CHGS_in = ['Stock_cattle','Stock_hog', 'Stock_gt_shp']
CHGS_out = ['Out_cattle', 'Out_hog','Out_gt_shp']
CHGS_yeild = ['MeatYeild_cattle', 'MeatYeild_hog', 'MeatYeild_gt_shp']
CHGS = CHGS_in + CHGS_out + CHGS_yeild

cattle_inout = ['Stock_cattle', 'Out_cattle']
hot_inout = ['Stock_hog', 'Out_hog']
gs_inout = ['Stock_gt_shp', 'Out_gt_shp']


# Outputs of poultry and yeilds of eggs 
birds_out = ['Out_poultry']
birds_egg = ['EggYeild']
birds = col_birds_out + col_birds_egg

# Yeilds of animal products for food
yeilds = ['MeatYeild_cattle', 'MeatYeild_hog', 'MeatYeild_gt_shp', 'MilkYeild_cattle', 'EggYeild']

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### National

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np

# %matplotlib inline

# %%
# create figure

fig = plt.figure()

fig_size = (20,5)
tit_size = 14
lab_size = 12
leg_size = 10
tck_size = 10

ax0 = fig.add_subplot(1,3,1) # add subplot 1 (2 row, 2 columns, 1st plot)
ax1 = fig.add_subplot(1,3,2)
ax2 = fig.add_subplot(1,3,3)

ax0.set_title('Stock of Cattle, Hog, and Goat&Sheep in China', fontsize=tit_size)
ax0.set_xlabel('Years', fontsize=lab_size)
ax0.set_ylabel('Number of Animals (10000 #)', fontsize=lab_size)


ax1.set_title('Outputs of Cattle, Hog, and Goat&Sheep in China',fontsize=tit_size)
ax1.set_ylabel('Number of Animals (10000 #)', fontsize=lab_size)
ax1.set_xlabel('Years', fontsize=lab_size)
# ax1.legend(['Cattle', 'Hog', 'Goat&Sheep'], loc='upper left', fontsize=leg_size)

ax2.set_title('Meat Yeilds of Cattle, Hog, and Goat&Sheep in China',fontsize=tit_size)
ax2.set_ylabel('Meat Yeilds (10000 t)', fontsize=lab_size)
ax2.set_xlabel('Years', fontsize=lab_size)
# ax2.legend(['Cattle', 'Hog', 'Goat&Sheep'], loc='upper left', fontsize=leg_size)


# 1st plot

ax_CHGS_in = df_data[col_AY+CHGS_in][df_data['AreaName']=='China'].plot(
    kind='line', x='Year', figsize=fig_size, ax=ax0)

ax_CHGS_in.spines['bottom'].set_visible(True)
ax_CHGS_in.spines['top'].set_visible(False)
ax_CHGS_in.spines['left'].set_visible(True)
ax_CHGS_in.spines['right'].set_visible(False)

ax0.legend(['Cattle', 'Hog', 'Goat & Sheep'], loc='upper left', fontsize=leg_size)

# # 2nd plot
# CHGS_out_cn = df_data[col_AY+CHGS_out][df_data['AreaName']=='China']
# CHGS_out_cn.plot(kind='line', x='Year', figsize=fig_size,
#                  ax=ax1)


# # 3rd plot
# CHGS_yeild_cn = df_data[col_AY+CHGS_yeild][df_data['AreaName']=='China']
# CHGS_yeild_cn.plot(kind='line', x='Year', figsize=fig_size,
#                    ax=ax2)


# plt.show()
