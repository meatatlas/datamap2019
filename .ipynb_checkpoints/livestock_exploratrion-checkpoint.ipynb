# %%
class ReadData():
    """
    # Usage:
    # df = ReadData(file_name, url).createDF() 
    """
    def __init__(self, file_name, 
                 url = None,
                 org_name = 'good-food', 
                 repo_name = 'datamap2019', 
                 folder_path = '/data/', 
                 mode = 'wb'
                ):
        
        self.file_name = file_name
        self.org_name = org_name
        self.repo_name = repo_name
        self.folder_path = folder_path
        
        self.url = url
        self.mode = mode
        
        self.root_path = 'https://github.com/'
        self.raw_path = 'https://raw.githubusercontent.com/'
        self.branch = 'master'

    def getPath(self):
        if self.url == None:
            path = self.root_path + self.org_name + '/' + self.repo_name + '/blob/' + self.branch + self.folder_path + self.file_name
            raw_path = self.raw_path + self.org_name + '/' + self.repo_name + '/' + self.branch + self.folder_path + self.file_name
        else:
            raw_path = self.url
            
        print('Url: ', path)
        print('Raw data:', raw_path)
        return raw_path

    def curl(self):
        import urllib.request, urllib.parse, urllib.error
        
        url = self.getPath()
        response = urllib.request.urlopen(url).read()
        with open(self.file_name, self.mode) as file_handle:
            file_handle.write(response)

    def delFile(self):
        import os

        if os.path.exists(self.file_name):
            os.remove(self.file_name)
        else:
            print('no such file:%s'%self.file_name)

    def createDF(self):
        import pandas as pd
        import time
        
        print(data_name, 'is under dealing... needs 1 min')
        self.curl()
        time.sleep(5)
        df = pd.read_csv(self.file_name)
        self.delFile()
        return df

# %%
# input
item = 'product_livestock'

# %%
data_name = item + '_clean.csv'
df_data = ReadData(data_name).createDF()
df_data.head()
# Out:
# product_livestock_clean.csv is under dealing... needs 1 min
# Url:  https://github.com/good-food/datamap2019/blob/master/data/product_livestock_clean.csv
# Raw data: https://raw.githubusercontent.com/good-food/datamap2019/master/data/product_livestock_clean.csv
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# <ipython-input-3-3f083c8fa67a> in <module>
#       1 data_name = item + '_clean.csv'
# ----> 2 df_data = ReadData(data_name).createDF()
#       3 df_data.head()
#
# <ipython-input-1-739e84b4c170> in createDF(self)
#      56
#      57         print(data_name, 'is under dealing... needs 1 min')
# ---> 58         self.curl()
#      59         time.sleep(5)
#      60         df = pd.read_csv(self.file_name)
#
# <ipython-input-1-739e84b4c170> in curl(self)
#      39
#      40         url = self.getPath()
# ---> 41         response = urllib.request.urlopen(url).read()
#      42         with open(self.file_name, self.mode) as file_handle:
#      43             file_handle.write(response)
#
# D:\ProgramData\Anaconda3\lib\http\client.py in read(self, amt)
#     458             else:
#     459                 try:
# --> 460                     s = self._safe_read(self.length)
#     461                 except IncompleteRead:
#     462                     self._close_conn()
#
# D:\ProgramData\Anaconda3\lib\http\client.py in _safe_read(self, amt)
#     610             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     611             if not chunk:
# --> 612                 raise IncompleteRead(b''.join(s), amt)
#     613             s.append(chunk)
#     614             amt -= len(chunk)
#
# IncompleteRead: IncompleteRead(144031 bytes read, 2696 more expected)

# %%
doc_name = item + '_doc.csv'
df_doc = ReadData(doc_name).createDF()
df_doc
# Out:
# product_livestock_clean.csv is under dealing... needs 1 min
# Url:  https://github.com/good-food/datamap2019/blob/master/data/product_livestock_doc.csv
# Raw data: https://raw.githubusercontent.com/good-food/datamap2019/master/data/product_livestock_doc.csv
#                  Feild name                   中文解释  \
# 0                  AreaName                地区 (省级)
# 1                      Year                     年份
# 2            Stock_largeAni    大动物存栏量 (牛&马&驴&骡&骆驼)
# 3              Stock_cattle                   牛存栏量
# 4               Stock_horse                   马存栏量
# 5              Stock_donkey                   驴存栏量
# 6                Stock_mule                   骡存栏量
# 7               Stock_camel                  骆驼存栏量
# 8                   Out_hog                   猪出栏量
# 9                 Stock_hog                   猪存栏量
# 10             Stock_gt_shp           羊存栏量 (绵羊&山羊)
# 11               Stock_goat                  山羊存栏量
# 12              Stock_sheep                  绵羊存栏量
# 13               Out_cattle                   牛出栏量
# 14               Out_gt_shp                   羊出栏量
# 15              Out_poultry                  家禽出栏量
# 16                MeatYeild            肉类产量 (所有品类)
# 17   MeatYeild_hg_ct_gt_shp  主要家畜的肉类产量 (牛&猪&山羊&绵羊)
# 18            MeatYeild_hog                   猪肉产量
# 19         MeatYeild_cattle                   牛肉产量
# 20         MeatYeild_gt_shp           羊肉产量 (山羊&绵羊)
# 21                MilkYeild             奶产量 (所有品类)
# 22         MilkYeild_cattle                   牛奶产量
# 23          WoolYeild_sheep        绵羊毛产量 (所有绵羊毛品类)
# 24     WoolYeild_sheep_fine                 细绵羊毛产量
# 25     WoolYeild_sheep_semi                半细绵羊毛产量
# 26     WoolYeild_goat_thick                 粗山羊毛产量
# 27  WoolYeild_goat_cashmere                  山羊绒产量
# 28                 EggYeild                   禽蛋产量
# 29               HoneyYeild                   蜂蜜产量
#
#                                 Explanation     单位: Unit
# 0                         Area (provincial)          Nan
# 1                                      Year          Nan
# 2   Stock of cattle&hores&donkey&mule&camel  万只: 10000 #
# 3                           Stock of cattle  万只: 10000 #
# 4                            Stock of horse  万只: 10000 #
# 5                           Stock of donkey  万只: 10000 #
# 6                             Stock of mule  万只: 10000 #
# 7                            Stock of camel  万只: 10000 #
# 8                             Output of hog  万只: 10000 #
# 9                              Stock of hog  万只: 10000 #
# 10                      Stock of sheep&goat  万只: 10000 #
# 11                            Stock of goat  万只: 10000 #
# 12                           Stock of sheep  万只: 10000 #
# 13                         Output of cattle  万只: 10000 #
# 14                          Output of sheep  万只: 10000 #
# 15                        Output of poultry  万只: 10000 #
# 16    Meat yeild from all kind of livestock  万吨: 10000 t
# 17    Meat yeild from cattle&hog&goat&sheep  万吨: 10000 t
# 18                      Meat yeild from hog  万吨: 10000 t
# 19                   Meat yeild from cattle  万吨: 10000 t
# 20               Meat yeild from goat&sheep  万吨: 10000 t
# 21    Milk yeild from all kind of livestock  万吨: 10000 t
# 22                   Milk yeild from cattle  万吨: 10000 t
# 23            Wool yeild from sheep (total)         吨: t
# 24             Wool yeild from sheep (fine)         吨: t
# 25        Wool yeild from sheep (semi-fine)         吨: t
# 26             Wool yeild from goat (thick)         吨: t
# 27          Wool yeild from goat (cashmere)         吨: t
# 28                   Egg yeild from poultry  万吨: 10000 t
# 29                              Honey yeild  万吨: 10000 t

# %%
# copy a copy of data
df = df_data

# %% [markdown]
# ## Group the Columns We Interested in
#
# We are interested in the following columns, and they can be grouped for further analysis (the columns may overlaped in defferent groups):
#
# - Cattle, hog, goat&sheep ('CHGS' for short):
#     - 'Stock_cattle', 'Stock_hog', 'Stock_gt_shp',
#     - 'Out_cattle', 'Out_hog', 'Out_gt_shp'
#     - 'MeatYeild_cattle', 'MeatYeild_hog', 'MeatYeild_gt_shp'
#     - 'Stock_cattle', 'Out_cattle'
#     - 'Stock_hog', 'Out_hog'
#     - 'Stock_gt_shp', 'Out_gt_shp'
#
#
# - Poultry ('birds' for short):
#     - 'Out_poultry',
#     - 'EggYeild'
#
#
# - Animal product yeilds ('yeilds' for short):
#     - 'MeatYeild_cattle', 'MeatYeild_hog', 'MeatYeild_gt_shp', 'MilkYeild', 'EggYeild'

# %%
# Stocks, outputs, and meat yeilds of cattle, hog, and goat&sheep.
CHGS_in = ['Stock_hog','Stock_cattle','Stock_gt_shp']
CHGS_out = ['Out_hog', 'Out_cattle','Out_gt_shp']
CHGS_yeild = ['MeatYeild_hog', 'MeatYeild_cattle', 'MeatYeild_gt_shp']
CHGS = CHGS_in + CHGS_out + CHGS_yeild

cattle_inout = ['Stock_cattle', 'Out_cattle']
hot_inout = ['Stock_hog', 'Out_hog']
gs_inout = ['Stock_gt_shp', 'Out_gt_shp']

# Outputs of poultry and yeilds of eggs 
birds_out = ['Out_poultry']
birds_egg = ['EggYeild']
birds = birds_out + birds_egg

# Yeilds of animal products for food
yeilds = ['MeatYeild_hog', 'MeatYeild_cattle', 'MeatYeild_gt_shp', 'MilkYeild_cattle', 'EggYeild']

# AreaNames and Years
AY = ['AreaName', 'Year']

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### China's National Production of Hog, Cattle, and Goat&Sheep

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np

# %matplotlib inline

# %%
# create figure
fig = plt.figure()

fig_size = (21,7)
tit_size = 16
lab_size = 14
leg_size = 12
tck_size = 12

# draw subplots
ax0 = fig.add_subplot(1,3,1)  # 2 row, 2 columns, 1st plot
plt.ylim(0,80000)

ax1 = fig.add_subplot(1,3,2)
plt.ylim(0,80000)

ax2 = fig.add_subplot(1,3,3)
plt.ylim(0,7000)

# draw data
ax0 = df[AY+CHGS_in][df['AreaName']=='China'].plot(
    kind='line', x='Year', figsize=fig_size, ax=ax0)

ax1 = df[AY+CHGS_out][df['AreaName']=='China'].plot(
    kind='line', x='Year', figsize=fig_size, ax=ax1)

ax2 = df[AY+CHGS_yeild][df['AreaName']=='China'].plot(
    kind='line', x='Year', figsize=fig_size,ax=ax2)

# set title, ylabel
ax0.set_title("China's National Stocks of\nHog, Cattle and Goat&Sheep", fontsize=tit_size)
ax0.set_ylabel('Number of Animals (10000 #)', fontsize=lab_size)

ax1.set_title("China's National Outputs of\nHog, Cattle and Goat&Sheep",fontsize=tit_size)
ax1.set_ylabel('Number of Animals (10000 #)', fontsize=lab_size)

ax2.set_title("China's National Meat Yeilds of\nHog, Cattle and Goat&Sheep",fontsize=tit_size)
ax2.set_ylabel('Meat Yeilds (10000 t)', fontsize=lab_size)

# set xlabels and legends
def setLabels(ax):
    ax.set_xlabel('Years', fontsize=lab_size)
    ax.legend(['Hog','Cattle', 'Goat&Sheep'], loc='upper left', fontsize=leg_size)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
for ax in [ax0, ax1, ax2]:
    setLabels(ax)
    
plt.show()

# %% [markdown]
# 图1：全国猪、牛、羊的年末存栏量（相当于养殖规模）
#
# 图2：全国猪、牛、羊的出栏量（相当于粗产量）
#
# 图3：全国猪肉、牛肉、羊肉的产量（屠宰去头、蹄、骨后的胴体重量）

# %% [markdown]
# ### Chinas National Animal Products for Food

# %%
# create figure
fig = plt.figure()

fig_size = (21,7)
tit_size = 16
lab_size = 14
leg_size = 12
tck_size = 12

# draw data
ax_yeilds_cn = df[AY+yeilds][df['AreaName']=='China'].plot(
    kind='line', x='Year', figsize=fig_size, ax=ax0)

ax_yeilds.set_title("China's National Animal Products for Food", fontsize=tit_size)
ax_yeilds.set_ylabel('Yeilds Weight (10000 t)', fontsize=lab_size)
ax_yeilds.set_xlabel('Years', fontsize=lab_size)
ax_yeilds.legend(labels=['Hog Meat','Cattle Meat', 'Goat&Sheep Meat', 'Cattle Milk', 'Egg'], loc='upper left', fontsize=leg_size)

ax_yeilds.spines['top'].set_visible(False)
ax_yeilds.spines['right'].set_visible(False)    

plt.show()

df[AY+yeilds]
# Out:
#            AreaName  Year  MeatYeild_hog  MeatYeild_cattle  MeatYeild_gt_shp  \
# 0             China  1996    3158.000000        355.700000        181.000000
# 1             China  1997    3596.300000        440.900000        212.800000
# 2             China  1998    3883.700000        479.900000        234.600000
# 3             China  1999    4005.600000        505.429400        251.264300
# 4             China  2000    4031.429225        532.805585        273.958296
# 5             China  2001    4184.476970        548.848436        292.683780
# 6             China  2002    4326.620730        584.607844        316.659378
# 7             China  2003    4518.610183        630.448090        357.243180
# 8             China  2004    4701.611405        675.871024        399.279134
# 9             China  2005    4555.327500        568.098800        350.060100
# 10            China  2006    4650.343031        590.332021        367.727146
# 11            China  2007    4307.851912        626.219166        385.679738
# 12            China  2008    4682.016502        617.679854        393.242622
# 13            China  2009    4932.846197        626.177738        399.431461
# 14            China  2010    5138.436655        629.068649        406.017853
# 15            China  2011    5131.647413        610.707092        397.964050
# 16            China  2012    5443.548494        614.746379        404.498933
# 17            China  2013    5618.599074        613.087333        409.900058
# 18            China  2014    5820.802302        615.722388        427.633152
# 19            China  2015    5645.409001        616.885977        439.932290
# 20            China  2016    5425.493760        616.905050        460.251005
# 21            China  2017    5451.796882        634.623418        471.068295
# 22          Beijing  1998      27.900000          2.100000          1.200000
# 23          Tianjin  1998      13.900000          2.300000          1.400000
# 24            Hebei  1998     219.100000         58.000000         21.800000
# 25           Shanxi  1998      42.800000          6.900000          6.200000
# 26   Inner Mongolia  1998      73.300000         17.600000         27.000000
# 27         Liaoning  1998     112.800000         23.400000          2.600000
# 28            Jilin  1998     117.200000         28.300000          2.600000
# 29     Heilongjiang  1998      83.500000         25.700000          3.000000
# ..              ...   ...            ...               ...               ...
# 612         Tianjin  2017      22.586310          3.390496          1.423884
# 613           Hebei  2017     291.469920         55.600000         30.100000
# 614          Shanxi  2017      62.669177          5.909839          8.555161
# 615  Inner Mongolia  2017      73.523987         59.484107        104.127593
# 616        Liaoning  2017     220.900000         25.110350          7.020000
# 617           Jilin  2017     136.143297         38.028096          4.867057
# 618    Heilongjiang  2017     159.307998         43.897380         12.899670
# 619        Shanghai  2017      14.570000          0.137886          0.346000
# 620         Jiangsu  2017     214.300000          2.931000          7.991000
# 621        Zhejiang  2017      83.310000          1.320000          2.360000
# 622           Anhui  2017     242.680075          8.074287         16.514344
# 623          Fujian  2017     128.371175          1.724800          1.935474
# 624         Jiangxi  2017     249.490000         12.046760          1.969780
# 625        Shandong  2017     427.441088         75.928893         36.027773
# 626           Henan  2017     466.900000         35.039787         26.100000
# 627           Hubei  2017     339.287112         15.759323          9.671157
# 628           Hunan  2017     449.600000         17.000000         14.937644
# 629       Guangdong  2017     277.963573          4.079770          1.963870
# 630         Guangxi  2017     254.967081         11.707239          3.323358
# 631          Hainan  2017      44.400000          1.847943          1.148508
# 632       Chongqing  2017     129.970000          7.288312          6.800000
# 633         Sichuan  2017     472.230274         33.310934         27.236834
# 634         Guizhou  2017     160.100000         19.060000          4.810000
# 635          Yunnan  2017     320.160989         35.820000         18.147887
# 636           Tibet  2017       1.140000         22.540000          6.350000
# 637         Shaanxi  2017      85.834229          8.332958          9.800000
# 638           Gansu  2017      49.882000         20.961000         22.758000
# 639         Qinghai  2017       8.670000         12.860000         12.680000
# 640         Ningxia  2017       8.907976         10.917891          9.906033
# 641        Xinjiang  2017      35.802410         43.040014         58.241447
#
#      MilkYeild_cattle     EggYeild
# 0          629.400000  1965.200000
# 1          601.100000  1895.300000
# 2          662.900000  2021.300000
# 3          717.593900  2134.667000
# 4          827.430790  2243.300000
# 5         1025.455158  2336.727116
# 6         1299.779402  2462.699342
# 7         1746.280616  2606.725813
# 8         2260.605825  2723.652309
# 9         2753.372900  2438.120100
# 10        2944.615111  2424.002796
# 11        2947.094580  2546.704847
# 12        3010.565012  2699.619220
# 13        2995.133443  2751.877202
# 14        3038.931042  2776.878812
# 15        3109.932313  2830.364533
# 16        3174.928519  2885.394316
# 17        3000.817191  2905.546923
# 18        3159.882894  2930.308356
# 19        3179.829022  3046.127163
# 20        3064.028959  3160.538660
# 21        3038.620948  3096.289071
# 22          22.700000    17.900000
# 23          11.700000    22.700000
# 24          55.800000   319.000000
# 25          30.100000    37.000000
# 26          63.800000    21.200000
# 27          18.500000   131.600000
# 28          12.400000    73.100000
# 29         142.100000    71.200000
# ..                ...          ...
# 612         52.050000    18.988879
# 613        381.005725   383.721654
# 614         77.391609   101.871059
# 615        552.857835    53.209200
# 616        119.708062   270.432820
# 617         33.980806   120.983557
# 618        465.214803   113.806821
# 619         36.370000     3.380000
# 620         49.044324   183.390000
# 621         14.308206    35.850000
# 622         29.841179   154.699829
# 623         13.113041    46.498142
# 624          9.494218    45.658107
# 625        223.543880   444.778057
# 626        202.857581   401.181632
# 627         12.757695   168.165927
# 628          6.051029   103.200000
# 629         13.883401    38.503995
# 630          8.141898    24.197661
# 631          0.499344     4.750000
# 632          5.058956    40.310000
# 633         63.701187   144.500000
# 634          4.404247    18.690000
# 635         56.831698    30.319051
# 636         37.060000     0.500000
# 637        107.275087    60.082440
# 638         40.400000    13.830500
# 639         32.427941     2.460000
# 640        160.065904    15.271177
# 641        191.860000    37.373828
#
# [642 rows x 7 columns]
